# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../TensorFlow_FILES/DATA/lending_club_loan_two.csv')

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %%
sns.countplot(data=df,x='loan_status')
# Out:
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\neeru\AppData\Local\Temp\ipykernel_5760\3735417154.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
sns.scatterplot(data=df,x='installment',y='loan_amnt')
# Out:
# <Axes: xlabel='installment', ylabel='loan_amnt'>

# %%
sns.scatterplot(data=df,x='total_acc',y='open_acc')
# Out:
# <Axes: xlabel='total_acc', ylabel='open_acc'>

# %%
plt.figure(figsize=(12,3))
sns.histplot(data=df,x='loan_amnt',bins=50)
# Out:
# <Axes: xlabel='loan_amnt', ylabel='Count'>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['grade'].sort_values()
# Out:
# 112879    A
# 164879    A
# 345121    A
# 345123    A
# 67441     A
#          ..
# 133024    G
# 349291    G
# 363022    G
# 295748    G
# 295080    G
# Name: grade, Length: 396030, dtype: object

# %%
df['sub_grade'].unique()
# Out:
# array(['B4', 'B5', 'B3', 'A2', 'C5', 'C3', 'A1', 'B2', 'C1', 'A5', 'E4',
#        'A4', 'A3', 'D1', 'C2', 'B1', 'D3', 'D5', 'D2', 'E1', 'E2', 'E5',
#        'F4', 'E3', 'D4', 'G1', 'F5', 'G2', 'C4', 'F1', 'F3', 'G5', 'G4',
#        'F2', 'G3'], dtype=object)

# %%
sns.countplot(data=df.sort_values('grade'),x='grade',hue='loan_status')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(12,4))
sns.countplot(data=df.sort_values('sub_grade'),x='sub_grade',palette='coolwarm',hue='loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
df['loan_repaid'] = df['loan_status'].apply(lambda x: {'Fully Paid':1,'Charged Off':0}[x])

# %%
df['loan_repaid'].value_counts()
# Out:
# 1    318357
# 0     77673
# Name: loan_repaid, dtype: int64

# %%
df.corrwith(df['loan_repaid']).drop('loan_repaid').sort_values().plot(kind='bar')
# Out:
# C:\Users\neeru\AppData\Local\Temp\ipykernel_5760\580323061.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corrwith(df['loan_repaid']).drop('loan_repaid').sort_values().plot(kind='bar')
# <Axes: >

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# ...

# %%
d = {'A':7,'B':6,'C':5,'D':4,'E':3,'F':2,'G':1}

df['grade_num'] = df['grade'].apply(lambda x: d[x])

# %%
df['grade_num']
# Out:
# 0         6
# 1         6
# 2         6
# 3         7
# 4         5
#          ..
# 396025    6
# 396026    5
# 396027    6
# 396028    5
# 396029    5
# Name: grade_num, Length: 396030, dtype: int64

# %%
df.head(3)
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
#
#          emp_title emp_length home_ownership  annual_inc  ... revol_bal  \
# 0        Marketing  10+ years           RENT    117000.0  ...   36369.0
# 1  Credit analyst     4 years       MORTGAGE     65000.0  ...   20131.0
# 2     Statistician   < 1 year           RENT     43057.0  ...   11987.0
#
#   revol_util total_acc initial_list_status application_type  mort_acc  \
# 0       41.8      25.0                   w       INDIVIDUAL       0.0
# 1       53.3      27.0                   f       INDIVIDUAL       3.0
# 2       92.2      26.0                   f       INDIVIDUAL       0.0
#
#   pub_rec_bankruptcies                                          address  \
# ...

# %% [markdown]
# Terms to remove
#
# 1. term
# 2. int_rate
# 3. sub_grade

# %%
grade_list = list(enumerate(df['sub_grade'].sort_values(ascending=False).unique()))

# %%
def enum(grade):
    for i in grade_list:
        if grade==i[1]:
            return i[0]

# %%
df['sub_grade_num'] = df['sub_grade'].apply(enum)

# %%
df['sub_grade_num']
# Out:
# 0         26
# 1         25
# 2         27
# 3         33
# 4         20
#           ..
# 396025    26
# 396026    24
# 396027    29
# 396028    23
# 396029    23
# Name: sub_grade_num, Length: 396030, dtype: int64

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   revol_util total_acc initial_list_status application_type mort_acc  \
# 0       41.8      25.0                   w       INDIVIDUAL      0.0
# ...

# %%
df.corrwith(df['loan_repaid']).drop('loan_repaid').sort_values().plot(kind='bar')
# Out:
# C:\Users\neeru\AppData\Local\Temp\ipykernel_5760\580323061.py:1: FutureWarning: The default value of numeric_only in DataFrame.corrwith is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corrwith(df['loan_repaid']).drop('loan_repaid').sort_values().plot(kind='bar')
# <Axes: >

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# Out:
# C:\Users\neeru\AppData\Local\Temp\ipykernel_5760\3735417154.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='coolwarm')
# <Axes: >

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'application_type',
#        'mort_acc', 'pub_rec_bankruptcies', 'address', 'loan_repaid',
#        'grade_num', 'sub_grade_num'],
#       dtype='object')

# %%
#X = df[['loan_amnt','int_rate','installment','open_acc',
#        'pub_rec','total_acc','pub_rec_bankruptcies',
#        'grade_num','sub_grade_num']]
X = df[['int_rate','grade_num','sub_grade_num']]

y = df['loan_repaid']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train.shape
# Out:
# (277221, 3)

# %%
model = Sequential()

model.add(Dense(3,activation='relu'))

model.add(Dense(15,activation='relu'))

model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam')

# %%
early_stop = EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=25)

# %%
model.fit(x=X_train,y=y_train,epochs=500,callbacks=[early_stop],validation_data=(X_test,y_test))
# Out:
# Epoch 1/500
# 8664/8664 [==============================] - 32s 4ms/step - loss: 0.4679 - val_loss: 0.4618
# Epoch 2/500
# 8664/8664 [==============================] - 28s 3ms/step - loss: 0.4617 - val_loss: 0.4613
# Epoch 3/500
# 8664/8664 [==============================] - 33s 4ms/step - loss: 0.4615 - val_loss: 0.4611
# Epoch 4/500
# 8664/8664 [==============================] - 34s 4ms/step - loss: 0.4613 - val_loss: 0.4610
# Epoch 5/500
# 8664/8664 [==============================] - 33s 4ms/step - loss: 0.4612 - val_loss: 0.4609
# Epoch 6/500
# 8664/8664 [==============================] - 35s 4ms/step - loss: 0.4612 - val_loss: 0.4611
# Epoch 7/500
# 8664/8664 [==============================] - 35s 4ms/step - loss: 0.4611 - val_loss: 0.4609
# Epoch 8/500
# 8664/8664 [==============================] - 34s 4ms/step - loss: 0.4610 - val_loss: 0.4609
# Epoch 9/500
# 8664/8664 [==============================] - 32s 4ms/step - loss: 0.4609 - val_loss: 0.4605
# Epoch 10/500
# ...

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
predictions = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 3713/3713 [==============================] - 8s 2ms/step

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,classes_x))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.20      1.00      0.33     23260
#            1       0.00      0.00      0.00     95549
#
#     accuracy                           0.20    118809
#    macro avg       0.10      0.50      0.16    118809
# weighted avg       0.04      0.20      0.06    118809
# C:\shobhit\coding\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\shobhit\coding\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print(confusion_matrix(y_test,classes_x))
# Out:
# [[23260     0]
#  [95549     0]]
